# %% [markdown]
# # Concept Overview
# ## Primary Key (PK)
#
#  - Uniquely identifies each row
#
#  - Cannot be NULL
#
#  - No duplicates
#
#  Think: "identity of the record"
#
# ## Foreign Key (FK)
#
#  - Links one table to another
#
#  - Ensures referential integrity
#
#  - Value must exist in the referenced table
#
#  Think: "relationship connector"

# %% [markdown]
# # Database Design
#
# We'll create:
#
#  - users → platform users
#
#  - products → items listed
#
#  - orders → purchase records

# %% [markdown]
# ### Load SQL Extension

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# ### show all databases
#     - SELECT datname FROM pg_database;
# ### Delete Database
#     - DROP DATABASE database_name;
# ### Create Databse
#     - CREATE DATABASE database_name;
#
# #### Run all these commands inside terminal after starting postgresql
#     - brew install postgresql
#     - brew services start postgresql
#     - psql postgres

# %% [markdown]
# ### Connect to PSQL Database

# %%
# First connect to default postgres database to create new database
# %sql postgresql://localhost/order_management_db

# %%
# %%sql
# select datname from pg_database;
# Out:
#  * postgresql://localhost/order_management_db
#    postgresql://localhost/postgres
# 5 rows affected.
# [('postgres',),
#  ('student_db',),
#  ('template1',),
#  ('template0',),
#  ('order_management_db',)]

# %% [markdown]
# ### Create Tables

# %% [markdown]
# ### User Table

# %%
# %%sql
# create table users(
#     user_id     INTEGER     PRIMARY KEY,
#     name        TEXT         NOT NULL,
#     email       TEXT         UNIQUE
# );
# Out:
#  * postgresql://localhost/order_management_db
#    postgresql://localhost/postgres
# Done.
# []

# %% [markdown]
# ### Product Table

# %%
# %%sql
# create table products (
#     product_id      INT     PRIMARY KEY,
#     product_name    text    not null,
#     price           real
# );
# Out:
#  * postgresql://localhost/order_management_db
#    postgresql://localhost/postgres
# Done.
# []

# %% [markdown]
# ### Oders Table

# %%
# %%sql
# create table orders (
#     order_id        int     primary key,
#     user_id         int,
#     product_id      int,
#     quantity        int,
#
#     foreign key     (user_id)        references users(user_id),
#     foreign key     (product_id)    references products(product_id)
# );
# Out:
#  * postgresql://localhost/order_management_db
#    postgresql://localhost/postgres
# Done.
# []

# %% [markdown]
# * `order_id` → Primary Key
# * `user_id` → Foreign Key
# * `product_id` → Foreign Key

# %% [markdown]
# ### Insert Sample Data

# %%
# %%sql
# insert into users (user_id, name, email) values
# (1, 'Flora', 'flora@gmail.com'),
# (2, 'Roni', 'roni@gmail.com');
# Out:
#  * postgresql://localhost/order_management_db
#    postgresql://localhost/postgres
# 2 rows affected.
# []

# %%
# %%sql
# select * from users;
# Out:
#  * postgresql://localhost/order_management_db
#    postgresql://localhost/postgres
# 2 rows affected.
# [(1, 'Flora', 'flora@gmail.com'), (2, 'Roni', 'roni@gmail.com')]

# %%
# %%sql
# insert into products (product_id, product_name, price) values
# (101, 'MacBook', '100000'),
# (102, 'iPhone', '10000');
# Out:
#  * postgresql://localhost/order_management_db
#    postgresql://localhost/postgres
# (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "products_pkey"
# DETAIL:  Key (product_id)=(101) already exists.
#
# [SQL: insert into products (product_id, product_name, price) values
# (101, 'MacBook', '100000'),
# (102, 'iPhone', '10000');]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %%
# %%sql
# select * from products;
# Out:
#  * postgresql://localhost/order_management_db
#    postgresql://localhost/postgres
# 2 rows affected.
# [(101, 'MacBook', 100000.0), (102, 'iPhone', 10000.0)]

# %%
# %%sql
# insert into orders (order_id, user_id, product_id, quantity) values
# (1,2,102,3),
# (2,1,101,2);
# Out:
#  * postgresql://localhost/order_management_db
#    postgresql://localhost/postgres
# 2 rows affected.
# []

# %%
# %%sql
# select * from orders;
# Out:
#  * postgresql://localhost/order_management_db
#    postgresql://localhost/postgres
# 2 rows affected.
# [(1, 2, 102, 3), (2, 1, 101, 2)]

# %% [markdown]
# ### important
# * PK → used for **indexing & fast lookup**
# * FK → enables **JOIN operations**
# * Relationships → foundation for:
#
# * Feature engineering
# * Data modeling
# * ETL pipelines

# %% [markdown]
# ### Quick Summary
#
# | Concept     | Meaning                           |
# | ----------- | --------------------------------- |
# | Primary Key | Unique row identifier             |
# | Foreign Key | Reference to another table        |
# | Goal        | Maintain structured relationships |
